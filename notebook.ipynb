# %% [markdown]
# # Imports

# %%
# !git clone https://github.com/SimoneRoma21/PKMN_VictoryBinaryClassification.git
# Out:
# MrPanas
# Cloning into 'PKMN_VictoryBinaryClassification'...
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/SimoneRoma21/PKMN_VictoryBinaryClassification.git/'
